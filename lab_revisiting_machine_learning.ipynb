# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('learningSet_new.csv',low_memory=False)

# %%
data.head()
# Out:
#    ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE   DOB NOEXCH  \
# 0     8901     GRI      0    IL  61081        A      NaN  3712      0
# 1     9401     BOA      1    CA  91326        A      NaN  5202      0
# 2     9001     AMH      1    NC  27017        A      NaN     0      0
# 3     8701     BRY      0    CA  95953        A      NaN  2801      0
# 4     8601     NaN      0    FL  33176        A      NaN  2001      0
#
#   RECINHSE  ... TARGET_D HPHONE_D RFA_2R RFA_2F RFA_2A  MDMAUD_R  MDMAUD_F  \
# 0      NaN  ...      0.0        0      L      4      E         X         X
# 1      NaN  ...      0.0        0      L      2      G         X         X
# 2      NaN  ...      0.0        1      L      4      E         X         X
# 3      NaN  ...      0.0        1      L      4      E         X         X
# 4        X  ...      0.0        1      L      2      F         X         X
#
#   MDMAUD_A CLUSTER2 GEOCODE2
# 0        X     39.0        C
# 1        X      1.0        A
# ...

# %%
df =data.copy()

# %%
df.describe()
# Out:
#             ODATEDW         TCODE           DOB       CLUSTER           AGE  \
# count  95412.000000  95412.000000  95412.000000  93096.000000  71747.000000
# mean    9141.363256     54.223117   2723.602933     27.922553     61.611649
# std      343.454752    953.844476   2132.241295     14.449652     16.664199
# min     8306.000000      0.000000      0.000000      1.000000      1.000000
# 25%     8801.000000      0.000000    201.000000     15.000000     48.000000
# 50%     9201.000000      1.000000   2610.000000     28.000000     62.000000
# 75%     9501.000000      2.000000   4601.000000     40.000000     75.000000
# max     9701.000000  72002.000000   9710.000000     53.000000     98.000000
#
#             NUMCHLD        INCOME       WEALTH1           HIT       MBCRAFT  \
# count  12386.000000  74126.000000  50680.000000  95412.000000  42558.000000
# mean       1.527773      3.886248      5.345699      3.321438      0.152075
# ...

# %%
df.shape
# Out:
# (95412, 481)

# %% [markdown]
# - Check for null values in all the columns

# %%
df.isna().sum()
# Out:
# ODATEDW       0
# OSOURCE     928
# TCODE         0
# STATE         0
# ZIP           0
#            ...
# MDMAUD_R      0
# MDMAUD_F      0
# MDMAUD_A      0
# CLUSTER2    132
# GEOCODE2    319
# Length: 481, dtype: int64

# %%
drop_list =[]

# %%
df = df.drop(columns=['OSOURCE','ZIP'],axis=1)

# %%
df
# Out:
#        ODATEDW  TCODE STATE MAILCODE PVASTATE   DOB NOEXCH RECINHSE RECP3  \
# 0         8901      0    IL        A      NaN  3712      0      NaN   NaN
# 1         9401      1    CA        A      NaN  5202      0      NaN   NaN
# 2         9001      1    NC        A      NaN     0      0      NaN   NaN
# 3         8701      0    CA        A      NaN  2801      0      NaN   NaN
# 4         8601      0    FL        A      NaN  2001      0        X     X
# ...        ...    ...   ...      ...      ...   ...    ...      ...   ...
# 95407     9601      1    AK        A      NaN     0      0      NaN   NaN
# 95408     9601      1    TX        A      NaN  5001      0      NaN   NaN
# 95409     9501      1    MI        A      NaN  3801      0      NaN     X
# 95410     8601      0    CA        A      NaN  4005      0        X   NaN
# 95411     8801      2    NC        A      NaN  1801      0        X   NaN
#
#       RECPGVG  ... TARGET_D HPHONE_D RFA_2R  RFA_2F  RFA_2A MDMAUD_R MDMAUD_F  \
# ...

# %% [markdown]
# - Identify columns that over 85% missing values

# %%
def remove_null_value(dataframe,threshold):
    nulls_percent_df = pd.DataFrame(df.isna().sum()/len(df)).reset_index()
    nulls_percent_df.columns =['col_name','nulls_percentage']
    return list(nulls_percent_df[nulls_percent_df['nulls_percentage']>threshold]['col_name'].values)

# %%
drop_list = remove_null_value(df,0.85)
drop_list
# Out:
# ['PVASTATE',
#  'RECINHSE',
#  'RECP3',
#  'RECPGVG',
#  'RECSWEEP',
#  'CHILD03',
#  'CHILD07',
#  'CHILD12',
#  'CHILD18',
#  'NUMCHLD',
#  'SOLP3',
#  'SOLIH',
#  'MAJOR',
#  'COLLECT1',
#  'VETERANS',
#  'BIBLE',
#  'CATLG',
#  'HOMEE',
#  'CDPLAY',
#  'STEREO',
#  'PCOWNERS',
#  'PHOTO',
#  'CRAFTS',
#  'FISHER',
#  'GARDENIN',
#  'BOATS',
#  'WALKER',
#  'KIDSTUFF',
#  'CARDS',
#  'PLATES',
#  'RDATE_3',
#  'RDATE_4',
#  'RDATE_5',
#  'RDATE_6',
#  'RDATE_7',
#  'RDATE_10',
#  'RDATE_13',
#  'RDATE_15',
#  'RDATE_17',
#  'RDATE_20',
#  'RDATE_21',
#  'RDATE_23',
#  'RAMNT_3',
#  'RAMNT_4',
#  'RAMNT_5',
#  'RAMNT_6',
#  'RAMNT_7',
#  'RAMNT_10',
#  'RAMNT_13',
#  'RAMNT_15',
#  'RAMNT_17',
#  'RAMNT_20',
#  'RAMNT_21',
#  'RAMNT_23']

# %%
len(drop_list)
# Out:
# 54

# %% [markdown]
# - Remove those columns from the dataframe

# %%
df = df.drop(drop_list,axis=1)

# %%
df.shape
# Out:
# (95412, 425)

# %% [markdown]
# - Reduce the number of categories in the column GENDER. The column should only have either "M" for males, "F" for females, and "other" for all the rest

# %%
categoricals = df.select_dtypes(object)

# %%
categoricals
# Out:
#       STATE MAILCODE NOEXCH MDMAUD DOMAIN AGEFLAG HOMEOWNR GENDER PETS  \
# 0        IL        A      0   XXXX     T2     NaN      NaN      F  NaN
# 1        CA        A      0   XXXX     S1       E        H      M  NaN
# 2        NC        A      0   XXXX     R2     NaN        U      M  NaN
# 3        CA        A      0   XXXX     R2       E        U      F  NaN
# 4        FL        A      0   XXXX     S2       E        H      F  NaN
# ...     ...      ...    ...    ...    ...     ...      ...    ...  ...
# 95407    AK        A      0   XXXX     C2     NaN      NaN      M  NaN
# 95408    TX        A      0   XXXX     C1       E        H      M  NaN
# 95409    MI        A      0   XXXX     C3     NaN      NaN      M  NaN
# 95410    CA        A      0   XXXX     C1       E        H      F  NaN
# 95411    NC        A      0   C1CM     C1       E        U      F  NaN
#
#       PEPSTRFL  ... RFA_21 RFA_22 RFA_23 RFA_24 RFA_2R RFA_2A MDMAUD_R  \
# ...

# %%
print(categoricals['GENDER'].value_counts(dropna=False))
# Out:
# F      51277
# M      39094
# NaN     2957
# U       1715
# J        365
# C          2
# A          2
# Name: GENDER, dtype: int64

# %%
categoricals['GENDER'] = categoricals['GENDER'].fillna('F')

# %%
print(categoricals['GENDER'].value_counts(dropna=False))
# Out:
# F    54234
# M    39094
# U     1715
# J      365
# C        2
# A        2
# Name: GENDER, dtype: int64

# %%
def clean_gender(x):
    if x =='F':
        return 'F'
    elif x =='M':
        return 'M'
    else:
        return 'other'

# %%
categoricals['GENDER']= categoricals['GENDER'].apply(clean_gender)

# %%
print(categoricals['GENDER'].value_counts(dropna=False))
# Out:
# F        54234
# M        39094
# other     2084
# Name: GENDER, dtype: int64
